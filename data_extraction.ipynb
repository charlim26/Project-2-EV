# %%
import requests
from key import api_key 
from pprint import pprint 

base_url = "https://api.openchargemap.io/v3/poi/"

params = { 
    "output": "json",
    "countrycode": "US",
    "polyline": "gz_jHfjroVdkd@sa{@nwW~nr@|yw@utWd~a@pchBgeu@lteFhc~L_qxBxn]cygFtlvBm`qAyin@oq~Mszq@urzIa}CqlqHqneFucAcxlJtfQ??",
    "maxresults": "1000",
    "key": api_key
}

data = requests.get(base_url, params=params).json()

# %%
pprint(data)
# Out:
# [{'AddressInfo': {'AccessComments': 'Located in downtown Portland on SW Salmon '
#                                     'St. at the World Trade Center.',
#                   'AddressLine1': '121 SW Salmon St.',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '8886701646',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 162404,
#                   'Latitude': 45.51593108775012,
#                   'Longitude': -122.67509773458892,
#                   'Postcode': '97205',
#                   'RelatedURL': 'https://www.portlandgeneral.com/residential/electric-vehicles-charging-stations/electric-avenue',
#                   'StateOrProvince': 'Multnomah County',
#                   'Title': 'Downtown Portland Electric Avenue',
#                   'Town': 'Portland'},
#   'Connections': [{'Amps': None,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'IEC 62196-3 Configuration '
#                                                     'EE',
#                                       'ID': 32,
#                                       'IsDiscontinued': False,
#                                       'IsObsolete': False,
#                                       'Title': 'CCS (Type 1)'},
#                    'ConnectionTypeID': 32,
#                    'CurrentType': {'Description': 'Direct Current',
#                                    'ID': 30,
#                                    'Title': 'DC'},
#                    'CurrentTypeID': 30,
#                    'ID': 233224,
#                    'Level': {'Comments': '40KW and Higher',
#                              'ID': 3,
#                              'IsFastChargeCapable': True,
#                              'Title': 'Level 3:  High (Over 40kW)'},
#                    'LevelID': 3,
#                    'PowerKW': 50.0,
#                    'Quantity': 4,
#                    'Reference': None,
#                    'StatusType': {'ID': 50,
#                                   'IsOperational': True,
#                                   'IsUserSelectable': True,
#                                   'Title': 'Operational'},
#                    'StatusTypeID': 50,
#                    'Voltage': None},
#                   {'Amps': None,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'IEC 62196-3 Configuration '
#                                                     'AA',
#                                       'ID': 2,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'CHAdeMO'},
#                    'ConnectionTypeID': 2,
#                    'CurrentType': {'Description': 'Direct Current',
#                                    'ID': 30,
#                                    'Title': 'DC'},
#                    'CurrentTypeID': 30,
#                    'ID': 233225,
#                    'Level': {'Comments': '40KW and Higher',
#                              'ID': 3,
#                              'IsFastChargeCapable': True,
#                              'Title': 'Level 3:  High (Over 40kW)'},
#                    'LevelID': 3,
#                    'PowerKW': 50.0,
#                    'Quantity': 4,
#                    'Reference': None,
#                    'StatusType': {'ID': 50,
#                                   'IsOperational': True,
#                                   'IsUserSelectable': True,
#                                   'Title': 'Operational'},
#                    'StatusTypeID': 50,
#                    'Voltage': None},
#                   {'Amps': None,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': None,
#                    'CurrentTypeID': None,
#                    'ID': 233226,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 6.7,
#                    'Quantity': 2,
#                    'Reference': None,
#                    'StatusType': {'ID': 50,
#                                   'IsOperational': True,
#                                   'IsUserSelectable': True,
#                                   'Title': 'Operational'},
#                    'StatusTypeID': 50,
#                    'Voltage': None}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 1,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Manual Data Entry'},
#                    'DateLastImported': None,
#                    'ID': 1,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'Licensed under Creative Commons '
#                               'Attribution-ShareAlike 4.0 International (CC '
#                               'BY-SA 4.0)',
#                    'Title': 'Open Charge Map Contributors',
#                    'WebsiteURL': 'http://openchargemap.org'},
#   'DataProviderID': 1,
#   'DataProvidersReference': None,
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-01T00:02:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-08-01T06:36:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': '$5.00 flat fee per DC fast charging session and $3.00 '
#                      'flat fee per Level 2 charging session. An additional '
#                      'peak charging fee of $0.19 per kWh applies on weekdays '
#                      'from 3 PM to 8 PM. Monthly memberships are available at '
#                      'PortlandGeneral.com/ElectricAvenue and replace all flat '
#                      'fees with a single monthly payment of $25.00 (note: peak '
#                      'charging fees still apply). No parking meter payment '
#                      'required while vehicles are actively charging at '
#                      'Electric Avenue. The two-hour time limit still '
#                      'applies.\r\n'
#                      '\r\n'
#                      'Electric Avenue provides four 50 kW DC fast chargers '
#                      'with CHAdeMO & CCS/SAE connectors and two 6.7 kW Level 2 '
#                      'stations with EV Plug connectors.',
#   'ID': 162047,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': 6,
#   'OperatorID': 59,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': 'Part of the Shell group.',
#                    'ContactEmail': None,
#                    'FaultReportEmail': None,
#                    'ID': 59,
#                    'IsPrivateIndividual': False,
#                    'IsRestrictedEdit': False,
#                    'PhonePrimaryContact': None,
#                    'PhoneSecondaryContact': None,
#                    'Title': 'GreenLots',
#                    'WebsiteURL': 'http://www.greenlots.com'},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 200,
#                        'IsLive': True,
#                        'Title': 'Submission Published'},
#   'SubmissionStatusTypeID': 200,
#   'UUID': 'B55B32A3-25D7-4938-8E44-6994BED4507B',
#   'UsageCost': None,
#   'UsageType': {'ID': 5,
#                 'IsAccessKeyRequired': False,
#                 'IsMembershipRequired': False,
#                 'IsPayAtLocation': True,
#                 'Title': 'Public - Pay At Location'},
#   'UsageTypeID': 5,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': 'Located adjacent to a main highway',
#                   'AddressLine1': '10834 SE McLoughlin Blvd',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '+18559007854',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 162403,
#                   'Latitude': 45.44452590833373,
#                   'Longitude': -122.64234992398553,
#                   'Postcode': '97222',
#                   'RelatedURL': 'https://www.portlandgeneral.com/residential/electric-vehicles-charging-stations/electric-avenue',
#                   'StateOrProvince': 'Clackamas County',
#                   'Title': 'Milwaukie Electric Avenue',
#                   'Town': 'Milwaukie'},
#   'Connections': [{'Amps': None,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'IEC 62196-3 Configuration '
#                                                     'AA',
#                                       'ID': 2,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'CHAdeMO'},
#                    'ConnectionTypeID': 2,
#                    'CurrentType': {'Description': 'Direct Current',
#                                    'ID': 30,
#                                    'Title': 'DC'},
#                    'CurrentTypeID': 30,
#                    'ID': 233221,
#                    'Level': {'Comments': '40KW and Higher',
#                              'ID': 3,
#                              'IsFastChargeCapable': True,
#                              'Title': 'Level 3:  High (Over 40kW)'},
#                    'LevelID': 3,
#                    'PowerKW': 50.0,
#                    'Quantity': 4,
#                    'Reference': None,
#                    'StatusType': {'ID': 50,
#                                   'IsOperational': True,
#                                   'IsUserSelectable': True,
#                                   'Title': 'Operational'},
#                    'StatusTypeID': 50,
#                    'Voltage': None},
#                   {'Amps': None,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'IEC 62196-3 Configuration '
#                                                     'EE',
#                                       'ID': 32,
#                                       'IsDiscontinued': False,
#                                       'IsObsolete': False,
#                                       'Title': 'CCS (Type 1)'},
#                    'ConnectionTypeID': 32,
#                    'CurrentType': {'Description': 'Direct Current',
#                                    'ID': 30,
#                                    'Title': 'DC'},
#                    'CurrentTypeID': 30,
#                    'ID': 233222,
#                    'Level': {'Comments': '40KW and Higher',
#                              'ID': 3,
#                              'IsFastChargeCapable': True,
#                              'Title': 'Level 3:  High (Over 40kW)'},
#                    'LevelID': 3,
#                    'PowerKW': 50.0,
#                    'Quantity': 4,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': None},
#                   {'Amps': None,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': None,
#                    'CurrentTypeID': None,
#                    'ID': 233223,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 7.0,
#                    'Quantity': None,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': None}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 1,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Manual Data Entry'},
#                    'DateLastImported': None,
#                    'ID': 1,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'Licensed under Creative Commons '
#                               'Attribution-ShareAlike 4.0 International (CC '
#                               'BY-SA 4.0)',
#                    'Title': 'Open Charge Map Contributors',
#                    'WebsiteURL': 'http://openchargemap.org'},
#   'DataProviderID': 1,
#   'DataProvidersReference': None,
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-07-31T23:28:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-08-01T06:37:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': 'This is a municipal public charging location by the '
#                      'local utility provider Portland General Electric (they '
#                      'have several locations around Portland).  Greenlots '
#                      'manages the site.  This site has 4 CCS, 4 Chademo and 1 '
#                      'J1772 level 2 charger.  50 kw max.',
#   'ID': 162046,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': 1,
#   'OperatorID': 1,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': None,
#                    'ContactEmail': None,
#                    'FaultReportEmail': None,
#                    'ID': 1,
#                    'IsPrivateIndividual': None,
#                    'IsRestrictedEdit': None,
#                    'PhonePrimaryContact': None,
#                    'PhoneSecondaryContact': None,
#                    'Title': '(Unknown Operator)',
#                    'WebsiteURL': None},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 200,
#                        'IsLive': True,
#                        'Title': 'Submission Published'},
#   'SubmissionStatusTypeID': 200,
#   'UUID': '8C1200F3-7526-423F-A5EB-3A6CCADDC530',
#   'UsageCost': None,
#   'UsageType': {'ID': 6,
#                 'IsAccessKeyRequired': False,
#                 'IsMembershipRequired': False,
#                 'IsPayAtLocation': False,
#                 'Title': 'Private - For Staff, Visitors or Customers'},
#   'UsageTypeID': 6,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': '6am-12am daily',
#                   'AddressLine1': '10903 SE Oak St',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '888-264-2208',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 160721,
#                   'Latitude': 45.444009,
#                   'Longitude': -122.629551,
#                   'Postcode': '97222',
#                   'RelatedURL': 'https://voltacharging.com/',
#                   'StateOrProvince': 'OR',
#                   'Title': 'Walgreens #9544',
#                   'Town': 'Milwaukie'},
#   'Connections': [{'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 230737,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 2,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '151867',
#   'DataQualityLevel': 3,
#   'DateCreated': '2020-06-26T03:09:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 160364,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': 3293,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': None,
#                    'ContactEmail': 'info@revoltaegypt.com',
#                    'FaultReportEmail': None,
#                    'ID': 3293,
#                    'IsPrivateIndividual': False,
#                    'IsRestrictedEdit': False,
#                    'PhonePrimaryContact': None,
#                    'PhoneSecondaryContact': None,
#                    'Title': 'Revolta Egypt',
#                    'WebsiteURL': 'https://www.revoltaegypt.com/'},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': '64E41F3D-C1A6-43B3-B949-3D1501F19650',
#   'UsageCost': None,
#   'UsageType': {'ID': 1,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': None,
#                 'IsPayAtLocation': None,
#                 'Title': 'Public'},
#   'UsageTypeID': 1,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': '6am-12am daily',
#                   'AddressLine1': '11995 SE Sunnyside Rd',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '888-264-2208',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 160716,
#                   'Latitude': 45.430286,
#                   'Longitude': -122.539766,
#                   'Postcode': '97015',
#                   'RelatedURL': 'https://voltacharging.com/',
#                   'StateOrProvince': 'OR',
#                   'Title': 'Walgreens #15927',
#                   'Town': 'Happy Valley'},
#   'Connections': [{'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 230730,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 2,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '151795',
#   'DataQualityLevel': 3,
#   'DateCreated': '2020-06-26T03:09:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 160359,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': 3293,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': None,
#                    'ContactEmail': 'info@revoltaegypt.com',
#                    'FaultReportEmail': None,
#                    'ID': 3293,
#                    'IsPrivateIndividual': False,
#                    'IsRestrictedEdit': False,
#                    'PhonePrimaryContact': None,
#                    'PhoneSecondaryContact': None,
#                    'Title': 'Revolta Egypt',
#                    'WebsiteURL': 'https://www.revoltaegypt.com/'},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': '6FE94970-5CA3-41F6-8C90-2FC96C5FF5BB',
#   'UsageCost': None,
#   'UsageType': {'ID': 1,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': None,
#                 'IsPayAtLocation': None,
#                 'Title': 'Public'},
#   'UsageTypeID': 1,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': '24 hours daily',
#                   'AddressLine1': '4772 N Lombard St',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '888-758-4389',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 145074,
#                   'Latitude': 45.5800059,
#                   'Longitude': -122.7177148,
#                   'Postcode': '97203',
#                   'RelatedURL': 'http://www.chargepoint.com/',
#                   'StateOrProvince': 'OR',
#                   'Title': 'ONLY STATION',
#                   'Town': 'Portland'},
#   'Connections': [{'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 201243,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 2,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '92222',
#   'DataQualityLevel': 3,
#   'DateCreated': '2019-12-24T09:23:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 144722,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': 5,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': None,
#                    'ContactEmail': 'support@coulombtech.com',
#                    'FaultReportEmail': 'support@coulombtech.com',
#                    'ID': 5,
#                    'IsPrivateIndividual': False,
#                    'IsRestrictedEdit': None,
#                    'PhonePrimaryContact': '1-888-758-4389',
#                    'PhoneSecondaryContact': None,
#                    'Title': 'ChargePoint (Coulomb Technologies)',
#                    'WebsiteURL': 'http://www.chargepoint.net/'},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': '7002E88A-09E5-4037-A8DF-BC4027EE2879',
#   'UsageCost': None,
#   'UsageType': {'ID': 1,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': None,
#                 'IsPayAtLocation': None,
#                 'Title': 'Public'},
#   'UsageTypeID': 1,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': 'MO: Not Specified; TU: Not Specified; WE: '
#                                     'Not Specified; TH: Not Specified; FR: Not '
#                                     'Specified; SA: Not Specified; SU: Not '
#                                     'Specified',
#                   'AddressLine1': '2829 N Lombard St',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '800-663-5633',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 145070,
#                   'Latitude': 45.57734,
#                   'Longitude': -122.696163,
#                   'Postcode': '97217',
#                   'RelatedURL': 'http://www.semacharge.com/',
#                   'StateOrProvince': 'OR',
#                   'Title': 'Walgreens - Portland, OR #5572 |P805',
#                   'Town': 'Portland'},
#   'Connections': [{'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 201239,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 1,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '147842',
#   'DataQualityLevel': 3,
#   'DateCreated': '2019-12-24T09:23:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 144718,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': 39,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': None,
#                    'ContactEmail': None,
#                    'FaultReportEmail': None,
#                    'ID': 39,
#                    'IsPrivateIndividual': False,
#                    'IsRestrictedEdit': None,
#                    'PhonePrimaryContact': None,
#                    'PhoneSecondaryContact': None,
#                    'Title': 'SemaCharge Network',
#                    'WebsiteURL': 'http://www.semacharge.com'},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': 'A3EC0D13-4703-4E61-957E-F10DF876840A',
#   'UsageCost': None,
#   'UsageType': {'ID': 1,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': None,
#                 'IsPayAtLocation': None,
#                 'Title': 'Public'},
#   'UsageTypeID': 1,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': 'MO: 06:00am-06:00pm; TU: 06:00am-06:00pm; '
#                                     'WE: 06:00am-06:00pm; TH: 06:00am-06:00pm; '
#                                     'FR: 06:00am-06:00pm; SA: Closed; SU: '
#                                     'Closed',
#                   'AddressLine1': '4555 N Channell Ave',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '800-663-5633',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 145013,
#                   'Latitude': 45.5552659,
#                   'Longitude': -122.7027591,
#                   'Postcode': '97217',
#                   'RelatedURL': 'http://www.semacharge.com/',
#                   'StateOrProvince': 'OR',
#                   'Title': '531007 : Daimler Trucks North American '
#                            'Headquarters',
#                   'Town': 'Portland'},
#   'Connections': [{'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 201175,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 6,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '147846',
#   'DataQualityLevel': 3,
#   'DateCreated': '2019-12-24T09:23:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 144661,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': 39,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': None,
#                    'ContactEmail': None,
#                    'FaultReportEmail': None,
#                    'ID': 39,
#                    'IsPrivateIndividual': False,
#                    'IsRestrictedEdit': None,
#                    'PhonePrimaryContact': None,
#                    'PhoneSecondaryContact': None,
#                    'Title': 'SemaCharge Network',
#                    'WebsiteURL': 'http://www.semacharge.com'},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': 'C3041DE6-DF85-4188-B3F3-22F89CA06B68',
#   'UsageCost': None,
#   'UsageType': {'ID': 1,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': None,
#                 'IsPayAtLocation': None,
#                 'Title': 'Public'},
#   'UsageTypeID': 1,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': '24 hours daily\r\n'
#                                     'Public - Card key at all times',
#                   'AddressLine1': '2170 NW Raleigh St',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '877-455-3833',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 144905,
#                   'Latitude': 45.533935,
#                   'Longitude': -122.695452,
#                   'Postcode': '97210',
#                   'RelatedURL': 'https://www.evgo.com/',
#                   'StateOrProvince': 'OR',
#                   'Title': 'New Seasons',
#                   'Town': 'Portland'},
#   'Connections': [{'Amps': 100,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'IEC 62196-3 Configuration '
#                                                     'AA',
#                                       'ID': 2,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'CHAdeMO'},
#                    'ConnectionTypeID': 2,
#                    'CurrentType': {'Description': 'Direct Current',
#                                    'ID': 30,
#                                    'Title': 'DC'},
#                    'CurrentTypeID': 30,
#                    'ID': 201061,
#                    'Level': {'Comments': '40KW and Higher',
#                              'ID': 3,
#                              'IsFastChargeCapable': True,
#                              'Title': 'Level 3:  High (Over 40kW)'},
#                    'LevelID': 3,
#                    'PowerKW': 40.0,
#                    'Quantity': 1,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 400},
#                   {'Amps': 100,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'IEC 62196-3 Configuration '
#                                                     'EE',
#                                       'ID': 32,
#                                       'IsDiscontinued': False,
#                                       'IsObsolete': False,
#                                       'Title': 'CCS (Type 1)'},
#                    'ConnectionTypeID': 32,
#                    'CurrentType': {'Description': 'Direct Current',
#                                    'ID': 30,
#                                    'Title': 'DC'},
#                    'CurrentTypeID': 30,
#                    'ID': 201062,
#                    'Level': {'Comments': '40KW and Higher',
#                              'ID': 3,
#                              'IsFastChargeCapable': True,
#                              'Title': 'Level 3:  High (Over 40kW)'},
#                    'LevelID': 3,
#                    'PowerKW': 40.0,
#                    'Quantity': 1,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 400}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '93542',
#   'DataQualityLevel': 3,
#   'DateCreated': '2019-12-24T09:23:00Z',
#   'DateLastConfirmed': None,
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 144553,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': 15,
#   'OperatorInfo': {'AddressInfo': None,
#                    'BookingURL': None,
#                    'Comments': 'Imported by ADFC import',
#                    'ContactEmail': None,
#                    'FaultReportEmail': None,
#                    'ID': 15,
#                    'IsPrivateIndividual': False,
#                    'IsRestrictedEdit': False,
#                    'PhonePrimaryContact': None,
#                    'PhoneSecondaryContact': None,
#                    'Title': 'eVgo Network',
#                    'WebsiteURL': 'https://www.evgo.com/'},
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 50,
#                  'IsOperational': True,
#                  'IsUserSelectable': True,
#                  'Title': 'Operational'},
#   'StatusTypeID': 50,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': 'E02A436C-5EBD-46FC-820C-F08F4378A23B',
#   'UsageCost': None,
#   'UsageType': {'ID': 4,
#                 'IsAccessKeyRequired': True,
#                 'IsMembershipRequired': True,
#                 'IsPayAtLocation': False,
#                 'Title': 'Public - Membership Required'},
#   'UsageTypeID': 4,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': 'MON: 24 hours | TUE: 24 hours | WED: 24 '
#                                     'hours | THU: 24 hours | FRI: 24 hours | '
# ...
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 12670,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 1,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '37651',
#   'DataQualityLevel': 1,
#   'DateCreated': '2011-01-31T00:00:00Z',
#   'DateLastConfirmed': '2011-01-31T00:00:00Z',
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 3069,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': None,
#   'OperatorInfo': None,
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 0,
#                  'IsOperational': None,
#                  'IsUserSelectable': True,
#                  'Title': 'Unknown'},
#   'StatusTypeID': 0,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': 'B62710EF-DCF9-446F-A911-8E91DAD625DE',
#   'UsageCost': None,
#   'UsageType': {'ID': 1,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': None,
#                 'IsPayAtLocation': None,
#                 'Title': 'Public'},
#   'UsageTypeID': 1,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': 'Employee use only',
#                   'AddressLine1': '1709 SE 3rd Ave',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 2900,
#                   'Latitude': 45.510465,
#                   'Longitude': -122.663354,
#                   'Postcode': '97214',
#                   'RelatedURL': '',
#                   'StateOrProvince': 'OR',
#                   'Title': 'Oregon Electric Group',
#                   'Town': 'Portland'},
#   'Connections': [{'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': None,
#                                       'ID': 9,
#                                       'IsDiscontinued': False,
#                                       'IsObsolete': False,
#                                       'Title': 'NEMA 5-20R'},
#                    'ConnectionTypeID': 9,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 12559,
#                    'Level': {'Comments': 'Under 2 kW, usually domestic socket '
#                                          'types',
#                              'ID': 1,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 1 : Low (Under 2kW)'},
#                    'LevelID': 1,
#                    'PowerKW': 1.9,
#                    'Quantity': 3,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 120},
#                   {'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 159462,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 1,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '35557',
#   'DataQualityLevel': 1,
#   'DateCreated': '2011-01-31T00:00:00Z',
#   'DateLastConfirmed': '2011-08-25T00:00:00Z',
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 2899,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': None,
#   'OperatorInfo': None,
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 0,
#                  'IsOperational': None,
#                  'IsUserSelectable': True,
#                  'Title': 'Unknown'},
#   'StatusTypeID': 0,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': '3E0D8E3E-7E7B-4362-A55F-C984B597BAB7',
#   'UsageCost': None,
#   'UsageType': {'ID': 2,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': True,
#                 'IsPayAtLocation': None,
#                 'Title': 'Private - Restricted Access'},
#   'UsageTypeID': 2,
#   'UserComments': None},
#  {'AddressInfo': {'AccessComments': '24 hours daily',
#                   'AddressLine1': '1945 SE Water Ave',
#                   'AddressLine2': None,
#                   'ContactEmail': None,
#                   'ContactTelephone1': '800-955-6674',
#                   'ContactTelephone2': None,
#                   'Country': {'ContinentCode': 'NA',
#                               'ID': 2,
#                               'ISOCode': 'US',
#                               'Title': 'United States'},
#                   'CountryID': 2,
#                   'Distance': None,
#                   'DistanceUnit': 0,
#                   'ID': 2740,
#                   'Latitude': 45.508396,
#                   'Longitude': -122.664667,
#                   'Postcode': '97214',
#                   'RelatedURL': '',
#                   'StateOrProvince': 'OR',
#                   'Title': 'Oregon Museum of Science and Industry (OMSI) - '
#                            'South Parking Lot',
#                   'Town': 'Portland'},
#   'Connections': [{'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'NEMA 5-15R',
#                                       'ID': 22,
#                                       'IsDiscontinued': False,
#                                       'IsObsolete': False,
#                                       'Title': 'NEMA 5-15R'},
#                    'ConnectionTypeID': 22,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 15265,
#                    'Level': {'Comments': 'Under 2 kW, usually domestic socket '
#                                          'types',
#                              'ID': 1,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 1 : Low (Under 2kW)'},
#                    'LevelID': 1,
#                    'PowerKW': 1.9,
#                    'Quantity': 2,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 120},
#                   {'Amps': 16,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': {'Description': 'Alternating Current - '
#                                                   'Single Phase',
#                                    'ID': 10,
#                                    'Title': 'AC (Single-Phase)'},
#                    'CurrentTypeID': 10,
#                    'ID': 15266,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': 3.7,
#                    'Quantity': 2,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': 230},
#                   {'Amps': None,
#                    'Comments': None,
#                    'ConnectionType': {'FormalName': 'SAE J1772-2009',
#                                       'ID': 1,
#                                       'IsDiscontinued': None,
#                                       'IsObsolete': None,
#                                       'Title': 'Type 1 (J1772)'},
#                    'ConnectionTypeID': 1,
#                    'CurrentType': None,
#                    'CurrentTypeID': None,
#                    'ID': 20245,
#                    'Level': {'Comments': 'Over 2 kW, usually non-domestic '
#                                          'socket type',
#                              'ID': 2,
#                              'IsFastChargeCapable': False,
#                              'Title': 'Level 2 : Medium (Over 2kW)'},
#                    'LevelID': 2,
#                    'PowerKW': None,
#                    'Quantity': 1,
#                    'Reference': None,
#                    'StatusType': None,
#                    'StatusTypeID': None,
#                    'Voltage': None}],
#   'DataProvider': {'Comments': None,
#                    'DataProviderStatusType': {'ID': 20,
#                                               'IsProviderEnabled': True,
#                                               'Title': 'Automated Import'},
#                    'DateLastImported': '2020-09-16T05:35:30.773Z',
#                    'ID': 2,
#                    'IsApprovedImport': True,
#                    'IsOpenDataLicensed': True,
#                    'IsRestrictedEdit': False,
#                    'License': 'This data is provided by the National Renewable '
#                               'Energy Laboratory ("NREL"), which is operated '
#                               'by the Alliance for Sustainable Energy, LLC '
#                               '("Alliance"), for the U.S. Department of Energy '
#                               '("DOE"), and may be used for any purpose '
#                               'whatsoever.',
#                    'Title': 'afdc.energy.gov',
#                    'WebsiteURL': 'http://www.afdc.energy.gov/'},
#   'DataProviderID': 2,
#   'DataProvidersReference': '33378',
#   'DataQualityLevel': 1,
#   'DateCreated': '2011-04-30T00:00:00Z',
#   'DateLastConfirmed': '2011-08-25T00:00:00Z',
#   'DateLastStatusUpdate': '2020-06-26T03:09:00Z',
#   'DateLastVerified': None,
#   'DatePlanned': None,
#   'GeneralComments': None,
#   'ID': 2739,
#   'IsRecentlyVerified': False,
#   'MediaItems': None,
#   'MetadataValues': None,
#   'NumberOfPoints': None,
#   'OperatorID': None,
#   'OperatorInfo': None,
#   'OperatorsReference': None,
#   'ParentChargePointID': None,
#   'PercentageSimilarity': None,
#   'StatusType': {'ID': 0,
#                  'IsOperational': None,
#                  'IsUserSelectable': True,
#                  'Title': 'Unknown'},
#   'StatusTypeID': 0,
#   'SubmissionStatus': {'ID': 100,
#                        'IsLive': True,
#                        'Title': 'Imported and Published'},
#   'SubmissionStatusTypeID': 100,
#   'UUID': '32DA0F81-4915-4CB8-9234-9F2488F62FEA',
#   'UsageCost': None,
#   'UsageType': {'ID': 1,
#                 'IsAccessKeyRequired': None,
#                 'IsMembershipRequired': None,
#                 'IsPayAtLocation': None,
#                 'Title': 'Public'},
#   'UsageTypeID': 1,
#   'UserComments': None}]
