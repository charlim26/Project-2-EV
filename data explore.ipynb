# %%
import json

# %%
path = "Washington_state_electric_vehicles.json"

# %%
with open(path) as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
data['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'assetType', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
data['meta']['view']
# Out:
# {'id': 'f6w7-q2d2',
#  'name': 'Electric Vehicle Population Data',
#  'assetType': 'dataset',
#  'attribution': 'Department of Licensing',
#  'averageRating': 0,
#  'category': 'Transportation',
#  'createdAt': 1555435581,
#  'description': 'This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).',
#  'displayType': 'table',
#  'downloadCount': 7141,
#  'hideFromCatalog': False,
#  'hideFromDataJson': False,
#  'newBackend': True,
#  'numberOfComments': 0,
#  'oid': 33425620,
#  'provenance': 'official',
#  'publicationAppendEnabled': False,
#  'publicationDate': 1581032146,
#  'publicationGroup': 16109923,
#  'publicationStage': 'published',
#  'rowClass': '',
#  'rowsUpdatedAt': 1599582090,
#  'rowsUpdatedBy': 'nzip-b272',
#  'tableId': 16874569,
#  'totalTimesRated': 0,
#  'viewCount': 4479,
#  'viewLastModified': 1599582068,
#  'viewType': 'tabular',
# ...

# %%
data['data'][3]
# Out:
# ['row-sika_7659.x8hb',
#  '00000000-0000-0000-5269-5503450AC044',
#  0,
#  1599582070,
#  None,
#  1599582096,
#  None,
#  '{ }',
#  'WBY7Z2C58J',
#  'King',
#  'SEATTLE',
#  'WA',
#  '98136',
#  '2018',
#  'BMW',
#  'I3',
#  'Battery Electric Vehicle (BEV)',
#  'Clean Alternative Fuel Vehicle Eligible',
#  '114',
#  '44450',
#  '34',
#  '474613408',
#  'POINT (-122.38895500000001 47.537382)',
#  '7',
#  '37',
#  '3009']

# %%
type(data)
# Out:
# dict

# %%
import requests
from keys import OCMkey

base_url = "https://api.openchargemap.io/v3/poi/"
params = {
    "output": "json",
    "countrycode": "US",
    "boundingbox": "(49.0690435,-124.8245017),(45.9932977,-116.9130527)",
    "maxresults": "10000",
    "key": OCMkey
}

data = requests.get(base_url, params=params).json()

# %%
data[0].keys()
# Out:
# dict_keys(['DataProvider', 'OperatorInfo', 'UsageType', 'StatusType', 'SubmissionStatus', 'UserComments', 'PercentageSimilarity', 'MediaItems', 'IsRecentlyVerified', 'DateLastVerified', 'ID', 'UUID', 'ParentChargePointID', 'DataProviderID', 'DataProvidersReference', 'OperatorID', 'OperatorsReference', 'UsageTypeID', 'UsageCost', 'AddressInfo', 'Connections', 'NumberOfPoints', 'GeneralComments', 'DatePlanned', 'DateLastConfirmed', 'StatusTypeID', 'DateLastStatusUpdate', 'MetadataValues', 'DataQualityLevel', 'DateCreated', 'SubmissionStatusTypeID'])

# %%
data[1]
# Out:
# {'DataProvider': {'WebsiteURL': 'http://openchargemap.org',
#   'Comments': None,
#   'DataProviderStatusType': {'IsProviderEnabled': True,
#    'ID': 1,
#    'Title': 'Manual Data Entry'},
#   'IsRestrictedEdit': False,
#   'IsOpenDataLicensed': True,
#   'IsApprovedImport': True,
#   'License': 'Licensed under Creative Commons Attribution-ShareAlike 4.0 International (CC BY-SA 4.0)',
#   'DateLastImported': None,
#   'ID': 1,
#   'Title': 'Open Charge Map Contributors'},
#  'OperatorInfo': {'WebsiteURL': 'http://www.greenlots.com',
#   'Comments': 'Part of the Shell group.',
#   'PhonePrimaryContact': None,
#   'PhoneSecondaryContact': None,
#   'IsPrivateIndividual': False,
#   'AddressInfo': None,
#   'BookingURL': None,
#   'ContactEmail': None,
#   'FaultReportEmail': None,
#   'IsRestrictedEdit': False,
#   'ID': 59,
#   'Title': 'GreenLots'},
#  'UsageType': {'IsPayAtLocation': True,
#   'IsMembershipRequired': False,
#   'IsAccessKeyRequired': False,
#   'ID': 5,
# ...

# %%
from pprint import pprint

# %%
len(data)
# Out:
# 1013

# %%
states = [datum['AddressInfo']['StateOrProvince'] for datum in data]
states =[item  for item in states if ((item != None) & (item in ["Chelan County",'WA','Washington', 'Washington State']))]
states
# Out:
# ['WA',
#  'WA',
#  'WA',
#  'Washington',
#  'Washington',
#  'WA',
#  'WA',
#  'Washington',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
#  'WA',
# ...

# %%
import numpy as np 
np.unique(states)
# Out:
# array(['Chelan County', 'WA', 'Washington', 'Washington State'],
#       dtype='<U16')

# %%
filtered_data = [d for d in data if (d['AddressInfo']['StateOrProvince'] in ['Chelan County','WA','Washington', 'Washington State'])]

# %%
len(filtered_data)
# Out:
# 999

# %%
type(filtered_data)
# Out:
# list

# %%
final_data = {'data':filtered_data}

# %%
with open('OCM_WA_data.json', 'w') as outfile:
     json.dump(final_data, outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)

# %%
import random

# %%
random.
